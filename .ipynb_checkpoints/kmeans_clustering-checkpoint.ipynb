# %%
#import libs
import sys
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('TKAgg')

from matplotlib import pyplot as plt
import tensorflow as tf

import seaborn as sn
from sklearn.preprocessing import scale
from sklearn import decomposition
from sklearn.decomposition import PCA
import time

# %matplotlib inline

#TRAINING PARAMETERS

# %%
df = pd.read_csv("MRS_DATASETS.csv")

# %%
df.head(5)
# Out:
#                                            0  \
# 0     (444.921478747601+12124.121506713604j)
# 1   (281.41626128718417+12072.222047208743j)
# 2  (-12.457513459272832+12830.523879177614j)
# 3   (277.49217259845364+12266.885237801478j)
# 4     (417.0577571319702+12668.33641511955j)
#
#                                            1  \
# 0  (-22.542515814500106+1936.7458028859398j)
# 1   (267.71981263908003+1812.8010601920032j)
# 2    (210.53513669727323+1826.692813396633j)
# 3    (323.4084692736599+1669.9844887962663j)
# 4    (352.0716063188718+1680.8931389089612j)
#
#                                           2  \
# 0   (-813.626745514492+1638.5268787502002j)
# 1   (-879.4839353916279+1664.519099444524j)
# 2  (-780.2547384347025+1664.3840888685563j)
# 3   (-848.3115975259492+1684.931068276945j)
# 4  (-724.6196058110979+1742.5764599426054j)
#
#                                          3  \
# 0   (63.24399329439997+780.6927061143001j)
# 1  (146.7849923908752+1150.1165115272615j)
# ...

# %%
real_components = pd.read_csv("REAL_COMPONENTS.csv")
real_components.head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.189531 -0.288113 -0.454942 -0.270022 -0.143790 -0.287907 -0.306017
# 1 -0.240449 -0.247257 -0.433590 -0.218332 -0.265247 -0.242295 -0.272137
# 2 -0.206789 -0.163500 -0.387561 -0.235834 -0.283529 -0.190700 -0.221663
# 3 -0.151441 -0.218528 -0.409938 -0.207221 -0.254770 -0.244609 -0.237949
# 4 -0.147416 -0.203541 -0.378160 -0.201602 -0.187110 -0.191644 -0.199265
#
#           7         8         9    ...           18        19        20  \
# 0 -0.186208 -0.280215  2.560694    ...    -0.145767 -0.285652 -0.261856
# 1 -0.217314 -0.232428  2.553388    ...    -0.244655 -0.232487 -0.212267
# 2 -0.207582 -0.193945  2.608542    ...    -0.167447 -0.213370 -0.238672
# 3 -0.194852 -0.187829  2.660375    ...    -0.093871 -0.179731 -0.133482
# 4 -0.216718 -0.197661  2.672006    ...    -0.200163 -0.197930 -0.143480
#
#          21        22        23        24        25        26        27
# ...

# %%
class MRS_Clusterer:
    """A custom brain clustering algorithm combining K-Means techniques , Autoencoder and PCA"""
    def __init__(self,k):
        self.k = k    #number of clusters
        self.means=None
        self.batch_size = 7
        self.batch_shape =(self.batch_size, 2048,1, 1)
        self.mrs_data_input_shape =2048*28
        self.lr =0.001
        self.num_epochs = 50
        self.n_hidden =64*64
        self.X =tf.placeholder(tf.float32,[None,28])
        self.display_step=1
        self.data=self.load_dataset()


    def encoder(self):
        """Encoder hidden layer with relu activation"""
        layer_h1=tf.nn.relu(tf.add(tf.matmul(self.data, tf.random_normal([self.mrs_data_input_shape,self.n_hidden]),tf.random_normal([self.n_hidden]))))
        return layer_h1
        
        
    def decoder(self,X):
        """Decoder network"""
        layer_h2= tf.nn.relu(tf.add(tf.matmul(X, tf.transpose(tf.random_normal([self.mrs_data_input_shape,self.n_hidden])),tf.random_normal([self.mrs_data_input_shape]))))
        return layer_h2
    

    
    def pca(self):
        """performs principal component analysis using sklearn"""
        
        scaled_inputs = scale(self.data)
        cov_matrix = PCA(n_components =28)
        
        cov_matrix.fit(scaled_inputs)
        
        variance = cov_matrix.explained_variance_ratio_
        var =np.cumsum(np.round(cov_matrix.explained_variance_ratio_,decimals=3)*100)
        
    
        return plt.plot(var)
              
        
    def classify(self):
        """returns the index of the cluster closest to the input"""
        return min(range(self.k),key=lambda i: tf.pow(self.data -self.means[i]))
        
    def train(self):
        """training MRS autoencoder"""
        cost=tf.div(tf.reduce_sum(tf.square(tf.subtract(dataset,
                                                 self.decoder(self.encoder(self.data))))), 
                  tf.constant(float(self.batch_size)))        
        optimizeer =tf.train.GradientDescentOptimizer(lr).minimize(cost)
        init =tf.global_variable_initializer()
        started =time.time()
        with tf.Session() as sess:
            sess.run(init)
            total_batch = int(dataset.shape[1]/self.batch_size)
            
            for epoch in np.arange(num_epochs):
                for i in np.arange(total_batch):
                    batch_xs =get_next_batch(dataset,self.batch_size)
                    _,c =sess.run([optimizeer,cost],feed_dict={X:batch_xs})
                    if epoch%display_step ==0:
                        print("Epoch:", '%04d' % (epoch+1),"cost=", "{:.9f}".format(c))
            print("Optimization finished!")
        ended =time.time()
        print("Elapsed time:", ended-started)

    def log_func(x1, x2):
        return tf.multiply(x1, tf.log(tf.div(x1,x2)))

    def KL_Div(rho, rho_hat):
        inv_rho = tf.subtract(tf.constant(1.), rho)
        inv_rhohat = tf.subtract(tf.constant(1.), rho_hat)
        log_rho = logfunc(rho,rho_hat) + log_func(inv_rho, inv_rhohat)
        return log_rho

    def load_dataset(self):
        return pd.read_csv("REAL_COMPONENTS.csv")

    def get_next_batch(dataset, batch_size):
        batch= dataset[:batch_size]
        batch_shape = [batch_size] + mrs_data_input_shape
        return np.reshape(batch, batch_shape)

# %%
clusterer =MRS_Clusterer(k=22)
clusterer.encoder()

# %%
def pca(inputs):
    scaled_inputs = scale(inputs)
    cov_matrix = PCA(n_components =28)
    cov_matrix.fit(scaled_inputs)
    variance = cov_matrix.explained_variance_ratio_
    var =np.cumsum(np.round(cov_matrix.explained_variance_ratio_,decimals=3)*100)

    return var

# %%
pcas =pca(real_components)

# %%
#pca plots of real part of the MRS signals

plt.plot(pcas)

# %%
imag_components = pd.read_csv("IMAG_COMPONENTS.csv")
imag_components.head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0  2.172132  0.040421 -0.021982 -0.201484 -0.138673 -0.086219 -0.037615
# 1  2.153268 -0.016322 -0.040867 -0.170073 -0.045629  0.018599  0.051177
# 2  2.174687 -0.009965 -0.023841 -0.177249  0.018875  0.102319  0.039872
# 3  2.121309 -0.005105 -0.045840 -0.195696 -0.006215 -0.068160  0.025258
# 4  2.225101 -0.032898 -0.027208 -0.195775  0.010471 -0.022508 -0.036124
#
#           7         8         9    ...           18        19        20  \
# 0  0.061711  0.013726 -0.166498    ...     0.129834  0.009583 -0.058421
# 1  0.019558  0.014198 -0.141684    ...     0.056860  0.006884 -0.036581
# 2 -0.016831  0.022096 -0.155668    ...     0.049985  0.026775  0.008885
# 3  0.020388  0.016433 -0.127527    ...     0.125126  0.012388  0.005634
# 4  0.038896 -0.047752 -0.140283    ...    -0.024714  0.017176 -0.011211
#
#          21        22        23        24        25        26        27
# ...

# %%
#pca plots of imaginary part of the MRS signals
imag_pcas =pca(imag_components)
plt.plot(imag_pcas)
